    "Bronchitis": f(['0.4943707969097215', '0.528436831166123', '-0.21815179631725967', '0.3679625117435108', '-0.09646157998297665', '-0.13534564284828565', '-0.2607010824439798', '0.45245400582976575', '-0.22748937093245', '0.009138166868279682', '0.09444778370400234', '-0.2434358369390443', '-0.06263851865911516', '-0.1292952080359793', '-0.21341302530499812', '-0.38995163745841516', '-0.10857094527334116', '-0.21330712321539574', '-0.28244765483891965', '1.0610677702500657', '0.079854686096434', '0.567822569177017', '-0.08846206641563097', '-0.05557279554014807']),
    "Fatty Liver": f(['2.304655971829395', '0.3948230310075553', '0.31449680083607595', '1.5454149218536468', '-0.21591348268509747', '-0.14533533536286655', '-0.3981751834623739', '0.37898073159558093', '-0.41229219946726564', '0.18519594860572747', '0.8913076895014685', '0.10055366432674656', '0.014718152125642713', '-0.061721595244590755', '-0.09023484854281437', '-0.41230084383111004', '0.02967051306815177', '-0.24503974655280056', '-0.16680864069186194', '1.1629705501316103', '0.14588570272968235', '0.714082513334338', '0.5752402614876874', '0.1880963166146289'])
}, index=cols)

plt.figure(figsize=(10, 8))
sns.heatmap(df, cmap="coolwarm", center=0, annot=True, fmt=".2f")
plt.show()

# %%
cols_str = \
"chf_risk, chd_risk, heart_attack_risk, thyroid_problem_risk, chronic_bronchitis_risk, fatty_liver_risk"


cols = [c.strip() for c in cols_str.split(',')]

df = pd.DataFrame({
    "chol_mg_dl > 300 or \n glu_mg_dl > 140": f(['2.61971831', '2.20779221', '2.11618257', '1.41364785', '1.70981508', '1.03663565']),
    "alt_u_l > 25 and \n triglyc_mg_dl > 130": f(['0.90704225', '1.07575758', '1.12240664', '0.71440607', '0.76955903', '1.15184356']),
}, index=cols)

sns.heatmap(df, cmap="coolwarm", center=0, annot=True, fmt=".2f")
plt.show()

# %%
cols_str = \
"chd_relative_risk, fatty_liver_relative_risk, depression_relative_risk"


cols = [c.strip() for c in cols_str.split(',')]

df = pd.DataFrame({
    "vit_d < 30 and trouble sleeping": f(['1.12987013', '0.59052793', '2.80769231']),
}, index=cols)

sns.heatmap(df, cmap="coolwarm", center=0, annot=True, fmt=".2f")
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.DataFrame({
    "vit_d nmol/l": [5, 15, 25, 35, 45, 55, 65, 75],
    "Depression risk multiple": [12.82, 1.832, 1.125, 1.15, 0.97, 1.088, 1.04, 1.00]
})


plt.figure(figsize=(4, 3))
sns.lineplot(data=df, x="vit_d nmol/l", y="Depression risk multiple", marker='s')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 12
#       8 })
#       9
#      10
#      11 plt.figure(figsize=(4, 3))
# ---> 12 sns.lineplot(data=df, x="vit_d nmol/l", y="Depression risk multiplie", marker='s')
#      13 plt.show()
#
# File ~/conv/.venv/lib/python3.12/site-packages/seaborn/relational.py:485, in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     471 def lineplot(
#     472     data=None, *,
#     473     x=None, y=None, hue=None, size=None, style=None, units=None, weights=None,
#    (...)    481
#     482     # Handle deprecation of ci parameter
#     483     errorbar = _deprecate_ci(errorbar, ci)
# --> 485     p = _LinePlotter(
# ...
